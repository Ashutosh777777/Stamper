# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import wikipedia
from openai import OpenAI
from IPython.display import Markdown, display

# %%
# constants
MODEL_LLAMA = 'llama3.2'
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key="anything")

# %%
# set up environment


def explain_term(term, sentences=3):
    try:
        # Set language explicitly (optional)
        wikipedia.set_lang("en")

        # Get a summary of the term
        summary = wikipedia.summary(term, sentences=sentences)
        return summary

    except wikipedia.exceptions.DisambiguationError as e:
        return f"Your query is ambiguous. Did you mean one of these?\n{e.options[:5]}"

    except wikipedia.exceptions.PageError:
        return "Sorry, I could not find information on that term."

    except Exception as e:
        return f"An unexpected error occurred: {e}"

# %%
# here is the question; type over this to ask something new

system = """
Please explain what this particular sentence means in a simple and funky language, as if I am your friend and can understand things better in slangs.
"""

# %%
# Get gpt-4o-mini to answer, with streaming

# %%
# Get Llama 3.2 to answer
def answer(term):
    ans = ollama.chat.completions.create(model = MODEL_LLAMA, 
                                         messages = [
                                             {"role": "system", "content":system}, 
                                             {"role":"user", "content": term }
                                         ])
    result = ans.choices[0].message.content
    display(Markdown(result))

# %%
answer("LLM")
# Out:
# Yo, what's good?!
#
# So, LLM stands for Large Language Model. It's like a super smart AI that's trained on a TON of text data, which makes it really good at understanding and generating human-like language.
#
# Think of it like a robot chat buddy that can:
#
# * Learn from tons of books, articles, and conversations
# * Understand nuances of language (like sarcasm and idioms)
# * Create new content, like stories or even code!
#
# It's the basis for many cool AI tools, like chatbots, language translation, and even self-driving cars!
#
# So, are you feeling educated now?
